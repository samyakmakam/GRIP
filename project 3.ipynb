# %% [markdown]
# # Samyak M

# %% [markdown]
# # Task 3

# %% [markdown]
# # Exploratory Data Analysis-Retail(Super Store)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv(r'F:\Desktop\SampleSuperstore.csv')
d=pd.DataFrame(d)
d
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
d.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
d.isna().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
d.max()
# Out:
# Ship Mode       Standard Class
# Segment            Home Office
# Country          United States
# City                      Yuma
# State                  Wyoming
# Postal Code              99301
# Region                    West
# Category            Technology
# Sub-Category            Tables
# Sales                  22638.5
# Quantity                    14
# Discount                   0.8
# Profit                 8399.98
# dtype: object

# %%
d.min()
# Out:
# Ship Mode         First Class
# Segment              Consumer
# Country         United States
# City                 Aberdeen
# State                 Alabama
# Postal Code              1040
# Region                Central
# Category            Furniture
# Sub-Category      Accessories
# Sales                   0.444
# Quantity                    1
# Discount                    0
# Profit               -6599.98
# dtype: object

# %%
d.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
d['Sales'].sum()
# Out:
# 2297200.8603

# %%
d['Profit'].sum()
# Out:
# 286397.0217

# %%
plt.scatter(x=d['Discount'],y=d['Profit'])
plt.show()

# %%
sns.pairplot(d)

# %%
### graphical representation of category vs total sale quantity
df=d.groupby('Category')['Quantity'].sum()
plt.bar(d['Category'].unique(),df)
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.title('category (vs)  total sale quantity')
# Out:
# Text(0.5, 1.0, 'category (vs)  total sale quantity')

# %%
df=d.groupby('Category')['Quantity'].sum()
labels=d['Category'].unique()
colors=['r','g','b']
plt.pie(df,labels=labels,colors=colors)
plt.show()

# %%
### graphical representation of category vs total sale 
df=d.groupby('Category')['Sales'].sum()
plt.bar(d['Category'].unique(),df)
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('category (vs)  total sale ')
# Out:
# Text(0.5, 1.0, 'category (vs)  total sale ')

# %%
### category vs sales bar graph
plt.bar(d['Category'],d['Sales'])
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('category (vs) sale')
# Out:
# Text(0.5, 1.0, 'category (vs) sale')

# %%
sns.pairplot(data=d,hue='Sub-Category')

# %%
sns.catplot('Category',data=d,hue='Sub-Category',kind='count')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Ship Mode',data=d,hue='Segment',kind='count')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Country',data=d,hue='State',kind='count')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('Region',data=d)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
df=d.groupby('Region')['Quantity'].sum()
plt.pie(df,labels=d['Region'].unique(),autopct='%1.1f%%')
plt.show()

# %%
d['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(d['State'])
plt.xticks(rotation=90);
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dff=pd.Series(d['State'])
dff=pd.DataFrame(dff)
dff['Category']=d['Category']
dff['Quantity']=d['Quantity']
dff.set_index('Category')
dff.reindex()
# Out:
#            State         Category  Quantity
# 0       Kentucky        Furniture         2
# 1       Kentucky        Furniture         3
# 2     California  Office Supplies         2
# 3        Florida        Furniture         5
# 4        Florida  Office Supplies         2
# ...          ...              ...       ...
# 9989     Florida        Furniture         3
# 9990  California        Furniture         2
# 9991  California       Technology         2
# 9992  California  Office Supplies         4
# 9993  California  Office Supplies         2
#
# [9994 rows x 3 columns]

# %%
plt.figure(figsize=(50,25))
df_fur=dff.loc[dff.Category=='Furniture']
df0=pd.DataFrame({'x':df_fur['State'],'y':df_fur['Quantity']})
df_tec=dff.loc[dff.Category=='Technology']
df6=pd.DataFrame({'x':df_tec['State'],'y':df_tec['Quantity']})
df_o=dff.loc[dff.Category=='Office Supplies']
df7=pd.DataFrame({'x':df_o['State'],'y':df_o['Quantity']})
df0['hue']='Furniture'
df6['hue']='Technology'
df7['hue']='Offline Supplies'
res=pd.concat([df0,df6,df7])
sns.barplot(x='x',y='y',data=res,hue='hue')
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.legend(fontsize=35)
plt.show()

# %%
df10=d.groupby('City')['Quantity'].sum().reset_index().sort_values(by='Quantity',ascending=False)
df10.head(10)
# Out:
#               City  Quantity
# 329  New York City      3417
# 266    Los Angeles      2879
# 374   Philadelphia      1981
# 438  San Francisco      1935
# 452        Seattle      1590
# 207        Houston      1466
# 80         Chicago      1132
# 94        Columbus       836
# 437      San Diego       670
# 464    Springfield       649

# %%
plt.figure(figsize=(50,25))
sns.barplot(x=d['State'],y=d['Profit'],)
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=d['Category'],y=d['Profit'])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
sns.countplot(d['Region'])
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=d['Region'],y=d['Profit'],)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=d['Sub-Category'],y=d['Profit'],)
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
df10=d.groupby('Category')['Profit'].sum().sort_values(ascending=False)
plt.scatter(df10,d['Category'].unique())

# %%
plt.figure(figsize=(50,25))
df11=d.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
plt.bar(d['Sub-Category'].unique(),df11)
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %%
df12=d.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
df13=df12.head(10)
plt.figure(figsize=(50,25))
plt.bar(df13['City'],df13['Profit'])
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %%
df17=d.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
df18=df17.head(10)
plt.figure(figsize=(50,25))
plt.bar(df18['City'],df18['Sales'])
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %%
df12=d.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
df13=df12.tail(10)
plt.figure(figsize=(50,25))
plt.bar(df13['City'],df13['Profit'])
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %%
df17=d.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
df18=df17.tail(10)
plt.figure(figsize=(50,25))
plt.bar(df18['City'],df18['Sales'])
plt.xticks(rotation=90,fontsize=35)
plt.yticks(fontsize=35)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# # In central Region Furniture incures loss.

# %% [raw]
# From Visualization of the given data,we can conclude that:
# Data Quality : The quality of data is good as, there are no null values in dataset hence no need of data preprocessing.
# Profit : New York city ,Category of Technology has highest profit.
# Sales : New York city,Category of Technology has highest sales , Abilene has lowest sales.
# Loss : Philedelphia has highest loss.
# Total Profit : 2,86,397
# Total Sales : 22,97,200
# 'Standard Class' accounts for the majority of profit.
# 'Home Office' segment generate least sales.
# 'Copies' Sub-Category has highest loss.
# 'Colorado' state has highest loss.
# 'Vermont' state has highest profit.
# In central region Furniture incures loss.
# 'Florida','Oregon','Arizona','Illinois','Texas','Pennsylviania','Tennesse','North Carlina;,'Colorado', and 'Ohio' have noticeabily less Profit.

# %% [markdown]
# So if the supermarket concentrates on the areas where loss incurred they can correct the loopholes, henceforth make them to get more profit.
